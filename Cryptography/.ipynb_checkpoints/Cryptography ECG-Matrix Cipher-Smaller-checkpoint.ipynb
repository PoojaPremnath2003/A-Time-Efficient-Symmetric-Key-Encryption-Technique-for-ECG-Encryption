# %%
import wave
import matplotlib.pyplot as plt

# %%
file=wave.open('sig100.wav')

# %%
#no of channels in the file
#channel=no of sources from which the audio comes from- mono= from a single input
#stereo= from 2 sources (equivalent to sound from left and right headphones)
print("The no of channels is:",file.getnchannels())
# Out:
# The no of channels is: 2

# %%
#Frequency of the sample
#this gives the no of frames per second
s_rate=file.getframerate()
print("Sampling frequency",s_rate)
# Out:
# Sampling frequency 360

# %%
#no of bytes in every sample
print("No of bytes in a sample:",file.getsampwidth())
# Out:
# No of bytes in a sample: 2

# %%
#to find the total number of frames in the sample
n_frames=file.getnframes()
print(n_frames)
# Out:
# 650000

# %%
#to read frames of the wave file
data=file.readframes(20000) # to read n frames
print(data)
# Out:
# b'`\xfc`\xfe`\xfc`\xfe`\xfc`\xfe`\xfc`\xfe`\xfc`\xfe`\xfc`\xfe`\xfc`\xfe`\xfc`\xfe\x00\xfd\x00\xfe\xa0\xfc\x00\xfe`\xfc\xe0\xfd@\xfc\xe0\xfd\x00\xfc \xfe \xfc@\xfe\x00\xfc@\xfe\xa0\xfb`\xfe\x80\xfb\xa0\xfe`\xfb\xc0\xfe\xc0\xfb\xc0\xfe \xfc\x00\xff\xa0\xfb\x00\xff\x80\xfb\xa0\xfe@\xfb \xfe\x80\xfb\x00\xfe \xfc\xe0\xfd\xa0\xfc@\xfe \xfc\x00\xfe@\xfb\x00\xfe\xe0\xfa\xc0\xfd \xfa\xa0\xfd`\xfa\xc0\xfd\xe0\xf9\xa0\xfd\xc0\xf9@\xfd\x80\xf9\x00\xfd \xf9`\xfc \xf9\xa0\xfc \xf9`\xfd`\xf9\xa0\xfd\xa0\xf9`\xfd`\xf9\x00\xfd \xf9\xa0\xfc\xc0\xf8\xe0\xfc\xc0\xf8\xe0\xfc\xc0\xf8 \xfd\xc0\xf8 \xfd\xe0\xf8\xe0\xfc\xa0\xf8\x80\xfc`\xf8\x80\xfc\xe0\xf8\xc0\xfc \xf9\xe0\xfc \xf9\x80\xfc\x00\xf9`\xfc\xe0\xf8@\xfc`\xf8@\xfc\xc0\xf8\xc0\xfc\x80\xf8 \xfd\x00\xf9\xe0\xfc\xc0\xf8\xa0\xfc\x80\xf8\x00\xfc \xf8 \xfb\x00\xf8\x00\xfb\xa0\xf7\xe0\xfa\x00\xf7`\xfa`\xf6\xa0\xf9`\xf6\x80\xf8\xe0\xf5\xc0\xf8\xa0\xf4 \xfa\xe0\xf3\xc0\xfc\xe0\xf3 \xff`\xf5@\x01\xc0\xf7\x00\x03\x80\xfa\x00\x05@\xfe\xc0\x07\x00\x03\xe0\n`\t`\r\x80\x0f\x80\x0e\x80\x13\xe0\x0b\x00\x15@\x05 \x13\xe0\xfd\x00\r@\xfa@\x04\xc0\xf9\xe0\xfb\xa0\xfa\xe0\xf6\x80\xfb \xf5`\xfb`\xf5\x00\xfc\xc0\xf6@\xfc\xc0\xf7@\xfc\xe0\xf7\x80\xfb\xa0\xf7\x80\xfb`\xf7\x00\xfc\xc0\xf7\xe0\xfb\xe0\xf7\xc0\xfb \xf8\xe0\xfb@\xf8`\xfb\x00\xf8`\xfb\xa0\xf7`\xfb\x80\xf7\xc0\xfb\xe0\xf7\x00\xfc`\xf7 \xfc\xa0\xf7\xa0\xfb\xc0\xf7 \xfb\xa0\xf7`\xfb\xc0\xf7`\xfb\xe0\xf7\xa0\xfb\xc0\xf7\xa0\xfb\xc0\xf7 \xfb`\xf7@\xfb \xf7\x80\xfb\xa0\xf7\xe0\xfb\xe0\xf7\xc0\xfb`\xf8\xc0\xfb\x00\xf8\xc0\xfb\x00\xf8@\xfb\xc0\xf7`\xfb\x80\xf7\x80\xfb\xa0\xf7\xc0\xfb\x80\xf7\xa0\xfb`\xf7@\xfb \xf7\x00\xfb \xf7 \xfb\x80\xf7`\xfb\xc0\xf7\xc0\xfb\xc0\xf7\xc0\xfb\xc0\xf7`\xfb\x80\xf7 \xfb@\xf7\xa0\xfb\xe0\xf7\x00\xfb\xe0\xf7`\xfb\xc0\xf7\x80\xfb\xc0\xf7`\xfb\xa0\xf7\xe0\xfa\xa0\xf7@\xfb\x80\xf7\x80\xfb\xc0\xf7`\xfb\x80\xf7\x00\xfb@\xf7\xa0\xfa \xf7\xe0\xfa@\xf7\xc0\xfa`\xf7\x00\xfb\xc0\xf7`\xfb\x00\xf8\xe0\xfa\xa0\xf7\x00\xfb\xc0\xf7\xc0\xfa`\xf7\xe0\xfa\xc0\xf7`\xfb\xa0\xf7`\xfb\xa0\xf7\x00\xfb`\xf7\xa0\xfa`\xf7`\xfa \xf7\x80\xfa\x80\xf7\x00\xfb\x80\xf7\x00\xfb\xa0\xf7\xa0\xfa\xc0\xf7`\xfa@\xf7 \xfa@\xf7\xe0\xf9`\xf7\x00\xfa\xa0\xf7\x00\xfa\xa0\xf7\x00\xfa\xa0\xf7\xe0\xf9@\xf7\x80\xf9 \xf7\x80\xf9 \xf7`\xf9`\xf7`\xf9`\xf7\x00\xf9\xa0\xf7\xe0\xf8@\xf7\xa0\xf8\x00\xf7\xa0\xf8\x00\xf7\x80\xf8\x00\xf7\xc0\xf8\xe0\xf6\x80\xf8\x00\xf7 \xf8\xc0\xf6 \xf8`\xf6 \xf8\xc0\xf6 \xf8\x00\xf7@\xf8 \xf7@\xf8\x00\xf7\xe0\xf7\xa0\xf6\xc0\xf7\xa0\xf6\xe0\xf7\xe0\xf6 \xf8\xe0\xf6`\xf8\x00\xf7`\xf8\x00\xf7\xc0\xf8\xe0\xf6\xc0\xf8\xc0\xf6 \xf9 \xf7@\xf9\xc0\xf7\xe0\xf9\xe0\xf7\x00\xfa\xe0\xf7\xc0\xf9\xa0\xf7\xc0\xf9\x80\xf7 \xfa \xf8\x80\xfa\x80\xf8 \xfb\x80\xf8@\xfb\xc0\xf8@\xfb\xa0\xf8@\xfb\xc0\xf8\x80\xfb\xe0\xf8\x00\xfc \xf9`\xfc\xa0\xf9@\xfc\xc0\xf9\x00\xfc\xc0\xf9\x00\xfc`\xf9 \xfc\xa0\xf9`\xfc\xe0\xf9\x80\xfc@\xfa\x00\xfc\xe0\xf9@\xfc\xe0\xf9\xa0\xfb\xa0\xf9\xc0\xfb\xa0\xf9\x00\xfc\x00\xfa\x00\xfc\xc0\xf9@\xfc\xa0\xf9 \xfc\xe0\xf9\x00\xfc\xa0\xf9\xc0\xfb\xc0\xf9 \xfc\xc0\xf9 \xfc`\xf9@\xfc\x80\xf9\xe0\xfb\x80\xf9\xa0\xfb`\xf9\xe0\xfb@\xf9\xe0\xfb`\xf9\x00\xfc\x80\xf9\x00\xfc \xf9\x80\xfb\x00\xf9\xa0\xfb\xc0\xf8`\xfb \xf9\xe0\xfb@\xf9@\xfc\x80\xf9@\xfc\x00\xf9\xc0\xfb\x00\xf9`\xfb\xe0\xf8 \xfb \xf9@\xfb \xf9@\xfb`\xf9`\xfb@\xf9@\xfb\xe0\xf8\xc0\xfa\xc0\xf8 \xfb\x00\xf9@\xfb \xf9\x80\xfb\xe0\xf8\xe0\xfa\x00\xf9\xa0\xfa\x80\xf8`\xfa\x80\xf8\xc0\xfa`\xf8\xe0\xfa\xa0\xf8 \xfb\x80\xf8\x00\xfb@\xf8 \xfb@\xf8\xc0\xfa`\xf8\xa0\xfa\xa0\xf8\xe0\xfa\xe0\xf8`\xfb\xe0\xf8 \xfb\xc0\xf8 \xfb\xa0\xf8\x80\xfa@\xf8\x80\xfa\xc0\xf8\xc0\xfa\xa0\xf8\xa0\xfa\x80\xf8\x80\xfa`\xf8\x80\xfa@\xf8`\xfa\xe0\xf7\xc0\xfa@\xf8\x00\xfb\x80\xf8\xc0\xfa\xc0\xf8`\xfa@\xf8@\xfa\xe0\xf7`\xfa\xc0\xf7\x80\xfa \xf8@\xfa\x80\xf8\xc0\xfa`\xf8\xa0\xfa@\xf8\xa0\xfa\x00\xf8@\xfa\xc0\xf7\xa0\xfa\xe0\xf7\x80\xfa \xf8\xe0\xfa@\xf8\xe0\xfa`\xf8\xc0\xfa`\xf8\xa0\xfa@\xf8`\xfa\x80\xf8\xa0\xfa`\xf8\xa0\xfa\xc0\xf8\xa0\xfa\x80\xf8`\xfa\x80\xf8`\xfa`\xf8`\xfa`\xf8\xe0\xfa\xc0\xf8 \xfb\x00\xf9\xc0\xfa\xa0\xf8\xc0\xfa`\x ...

# %%
#The above o/p shows binary data
#There are 2 channels, and 2 bytes per channel= 4 bytes in all in a frame
#First two bytes= from 1st channel, next 2 bytes= from the next channel

# %%
#To decode the binary data
import numpy as np
op=np.frombuffer(data,np.int16)
print(op)
# Out:
# [ -928  -416  -928 ... -1760 -2240 -1728]

# %%
op.shape=-1,2
#-1 stands for all the rows, 2 for the number of columnns
print(op)
temp=op[:]
# Out:
# [[ -928  -416]
#  [ -928  -416]
#  [ -928  -416]
#  ...
#  [-2560 -1792]
#  [-2272 -1760]
#  [-2240 -1728]]

# %%
#in the above o/p, the first column= from the first channel
#second column= from the second column

# %%
#taking the transpose, so that each row= from one channel
op=op.T
print(op)
#new_op=(op[0:30])
#print(new_op)
# Out:
# [[ -928  -928  -928 ... -2560 -2272 -2240]
#  [ -416  -416  -416 ... -1792 -1760 -1728]]

# %%
#to make the time sequence
#1. Find the total duration of the file
#duration= n_frames/sampling_rate (sampling rate= no of samples per sec )
duration=20000/s_rate
print(duration)

#time difference between each sample
diff=1/s_rate
# Out:
# 55.55555555555556

# %%
#to generate a time sequence
t_seq=np.arange(0,duration,diff)
#the arrange function's params are initial and final val, and the step val

# %%
#to plot the first channel
plt.figure(figsize=(20,10))
plt.xlim(0,10)
plt.plot(t_seq,op[0])
plt.xlabel("Time")
plt.ylabel("Amplitude")
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
#to plot the second channel
plt.figure(figsize=(20,10))
plt.xlim(0,10)
plt.plot(t_seq,op[1])
plt.xlabel("Time")
plt.ylabel("Amplitude")
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
op.shape
# Out:
# (2, 20000)

# %%
temp=op.ravel()

# %%
temp.shape
# Out:
# (40000,)

# %%
a=np.array([temp])

# %%
a.shape
# Out:
# (1, 40000)

# %%
new=a.T

# %%
new.shape
# Out:
# (40000, 1)

# %%
new
# Out:
# array([[ -928],
#        [ -928],
#        [ -928],
#        ...,
#        [-1792],
#        [-1760],
#        [-1728]], dtype=int16)

# %%
def squarify(M,val):
    (a,b)=M.shape
    if a>b:
        padding=((0,0),(0,a-b))
    else:
        padding=((0,b-a),(0,0))
    return np.pad(M,padding,mode='constant',constant_values=val)

# %%
#trying to square the matrix, channel wise

# %%
#c1=np.array([op[1].copy()])

# %%
#c1_t=c1.T

# %%
#c1_t.shape

# %%
#square=squarify(c1_t,0)

# %%
#square.shape

# %%
square=squarify(new,0)

# %%
square.shape
# Out:
# (40000, 40000)

# %%
square
# Out:
# array([[ -928,     0,     0, ...,     0,     0,     0],
#        [ -928,     0,     0, ...,     0,     0,     0],
#        [ -928,     0,     0, ...,     0,     0,     0],
#        ...,
#        [-1792,     0,     0, ...,     0,     0,     0],
#        [-1760,     0,     0, ...,     0,     0,     0],
#        [-1728,     0,     0, ...,     0,     0,     0]], dtype=int16)

# %%
key=np.random.randn(40000,40000)
print(np.linalg.det(key))

# %%
key.shape

# %%
key

# %%
#encrypted matrix
enc=square*key

# %%
enc.shape

# %%
enc

# %%
var=np.linalg.inv(key)

# %%
np.linalg.det(key)

# %%
var
